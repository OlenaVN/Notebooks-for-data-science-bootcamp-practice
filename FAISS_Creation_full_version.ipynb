# %% [markdown]
# <a href="https://colab.research.google.com/github/OlenaVN/Notebooks-for-data-science-bootcamp-practice/blob/main/FAISS_Creation_full_version.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# install 'faiss-cpu' library

# %%
# !pip install faiss-cpu

# %%
import faiss

# %%
import numpy as np
data = np.random.rand( 100000 , 768 )

# %%
index = faiss.IndexFlatL2(768)

# %%
assert index.is_trained

# %%
index.add(data)

# %%
index.ntotal
# Out:
# 100000

# %%
query = np.random.rand(1,768)

# %%
D, I = index.search(query, 10 )

# %%
D
# Out:
# array([[108.74527 , 109.0101  , 109.89572 , ..., 111.02167 , 111.76456 ,
#         111.87735 ],
#        [108.37253 , 108.56036 , 109.428406, ..., 109.97061 , 110.039246,
#         110.406494],
#        [106.18399 , 106.249115, 106.48224 , ..., 108.28287 , 108.29547 ,
#         108.65738 ],
#        ...,
#        [106.26459 , 107.357086, 107.811646, ..., 108.341064, 108.67447 ,
#         108.759735],
#        [105.52994 , 105.72476 , 106.18707 , ..., 106.62247 , 106.66046 ,
#         106.71924 ],
#        [105.55884 , 107.08197 , 107.464325, ..., 109.07172 , 109.12955 ,
#         109.281555]], dtype=float32)

# %%
I
# Out:
# array([[20970, 93741, 57333, 50336, 69154, 14907, 32334, 26922, 59451,
#         32851]])

# %%
I[0,0]
# Out:
# np.int64(68773)
